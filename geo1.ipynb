# %% [markdown]
# <a href="https://colab.research.google.com/github/lee-yeonwoo/datacookingclass/blob/main/geo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install folium

# %%
pip install Geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0MB 5.5MB/s
# ...
#      |████████████████████████████████| 6.5MB 8.8MB/s
# ...
#      |████████████████████████████████| 14.8MB 279kB/s
# ...

# %%
import folium
import geopandas as gpd
folium.__version__
# Out:
# '0.8.3'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = '/older_population.csv'

# %%
data = pd.read_csv(df1)
data.head()
# Out:
#      구    동     인구    남자     여자
# 0  종로구  사직동   9700  4375   5325
# 1  종로구  삼청동   3013  1443   1570
# 2  종로구  부암동  10525  5002   5523
# 3  종로구  평창동  18830  8817  10013
# 4  종로구  무악동   8745  4078   4667

# %%
pip install Geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0MB 6.3MB/s
# ...
#      |████████████████████████████████| 14.8MB 235kB/s
# ...
#      |████████████████████████████████| 6.5MB 46.0MB/s
# ...

# %%
import io
import pandas as pd

# %%
import folium
import geopandas as gpd
import json

# %%
geo_data = gpd.read_file('/seoul-dong.geojson')

# %%
geo_data
# Out:
#          시    구  ...     행정동코드                                           geometry
# 0    서울특별시  종로구  ...  11110530  MULTIPOLYGON (((126.97689 37.57565, 126.97703 ...
# 1    서울특별시  종로구  ...  11110540  MULTIPOLYGON (((126.98269 37.59507, 126.98337 ...
# 2    서울특별시  종로구  ...  11110550  MULTIPOLYGON (((126.97585 37.59656, 126.97359 ...
# 3    서울특별시  종로구  ...  11110560  MULTIPOLYGON (((126.97507 37.63139, 126.97649 ...
# 4    서울특별시  종로구  ...  11110570  MULTIPOLYGON (((126.96067 37.58080, 126.96281 ...
# ..     ...  ...  ...       ...                                                ...
# 419  서울특별시  강동구  ...  11740690  MULTIPOLYGON (((127.14580 37.52199, 127.14564 ...
# 420  서울특별시  강동구  ...  11740700  MULTIPOLYGON (((127.15355 37.53400, 127.15357 ...
# 421  서울특별시  강동구  ...  11740570  MULTIPOLYGON (((127.14447 37.55477, 127.14319 ...
# 422  서울특별시  강동구  ...  11740610  MULTIPOLYGON (((127.13458 37.54712, 127.13115 ...
# ...

# %%
center = [37.541, 126.986]
m = folium.Map(location=center, zoom_start=10)

# %%
# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m = folium.Map(location=center, zoom_start=10)

# Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_data=geo_data,
    data=data,
    columns=('동', '인구'),
    key_on='feature.properties.동',
    fill_color='BuPu',
    legend_name='노령 인구수',
).add_to(m)

# 맵 m을 출력합니다.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
df = pd.read_csv('/toilet_seoul.csv')
df = df[['고유번호', '위도', '경도']]

df.head(3)
# Out:
#    고유번호         위도          경도
# 0    92  37.501401  127.158647
# 1    93  37.644937  127.073728
# 2    94  37.640335  127.077637

# %%
center = [37.541, 126.986]
m = folium.Map(location=center, zoom_start=10)

# 1000 개의 데이터만 그려냅니다.
for i in df.index[:1000]:
    folium.Circle(
        location = df.loc[i, ['위도', '경도']],
        tooltip = df.loc[i, '고유번호'],
        radius = 200
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
df2 = pd.read_csv('/busstop.csv')
df2 = df2[['정류장ID', 'lon', 'lat']]

df2.head(3)
# Out:
#        정류장ID         lon        lat
# 0  201000313  126.970983  37.256983
# 1  201000344  126.991029  37.244605
# 2  201000345  127.016000  37.251091

# %%
center = [37.269, 127.033]
m1 = folium.Map(location=center, zoom_start=12)

# 1000 개의 데이터만 그려냅니다.
for j in df2.index[:1000]:
    folium.Circle(
        location = df2.loc[j, ['lat', 'lon']],
        tooltip = df2.loc[j, '정류장ID'],
        radius = 100
    ).add_to(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
